# %% [markdown]
# Tried to retrain the model of the intel 2017 paper.

# %%
import tensorflow as tf 
import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 1.11.0
# 2.2.4
# Using TensorFlow backend.

# %%
## Checking the GPU configuration

from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15598663841786696838, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 7436052071
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 17762760728907579552
#  physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
timeNumberFrames = 1 #4 # number of frames in each samples
batchSize = 120 # size of batch
valBatchSize = 120 # size of batch for validation set
NseqVal = 5  # number of sequences to use for validation
# training parameters
epochs = 100
samplesPerEpoch = 500
L2NormConst = 0.001 
trainScratch = True

# Configurations
num_images = 657800 # 200 * 3289
memory_fraction=0.25
image_cut=[115, 510]
dropoutVec = [1.0] * 8 + [0.7] * 2 + [0.5] * 2 + [0.5] * 1 + [0.5, 1.] * 5
prefSize = _image_size = (88, 200, 3)
#batchSize = 120
learningRate = 0.0002 # multiplied by 0.5 every 50000 mini batch
iterNum = 294000
beta1 = 0.7
beta2 = 0.85
controlInputs = [2,5,3,4] # Control signal, int ( 2 Follow lane, 3 Left, 4 Right, 5 Straight)
cBranchesOutList = ['Follow Lane','Go Left','Go Right','Go Straight','Speed Prediction Branch'] 

branchConfig = [["Steer", "Gas", "Brake"], ["Steer", "Gas", "Brake"], \
                     ["Steer", "Gas", "Brake"], ["Steer", "Gas", "Brake"], ["Speed"]]
params = [trainScratch, dropoutVec, image_cut, learningRate, beta1, beta2, num_images, iterNum, batchSize, valBatchSize, NseqVal, epochs, samplesPerEpoch, L2NormConst]

# GPU configuration
config = tf.ConfigProto(allow_soft_placement = True)
config.gpu_options.visible_device_list = '0'
config.gpu_options.per_process_gpu_memory_fraction = memory_fraction

# %%
datasetDirTrain = '/home/inst/Downloads/AgentHuman/SeqTrain/'
datasetDirVal = '/home/inst/Downloads/AgentHuman/SeqVal/'

import glob
datasetFilesTrain = glob.glob(datasetDirTrain+'*.h5')
datasetFilesVal = glob.glob(datasetDirVal+'*.h5')

# %%
# vpcom Special function for visualization
def plotSpecialTool(data,labels,samples2Visualize=12,factors=[2,6], grayFlag=False, figSize=(12,3), fontsize = 7):
    # samples2Visualize = 12 # sample 12 random number
    # factors = [2,6] # indicate two factors for number of samples
    assert np.prod(np.array(factors))==samples2Visualize, "%rx%r is not equal to %r" % (factors[0],factors[1],samples2Visualize)
    figure = plt.figure(figsize=figSize)
    nLimit = data.shape[0]
    for i in range(1,samples2Visualize+1):
        img = figure.add_subplot(factors[0],factors[1],i)
        # randomly sample an image from train set
        imgID = np.random.randint(nLimit-1)
        image = data[imgID]
        if grayFlag:
            plt.imshow(image.reshape(image.shape[0],image.shape[1]), cmap=plt.get_cmap('gray'))
        else:
            plt.imshow(image)
        img.set_title(["{:06.4f}".format(x) for x in labels[imgID]],fontsize=fontsize)
        plt.axis('off')

# %%
# %pwd
# Out:
# '/home/inst/Desktop/GitHUB/Carla_Training'

# %%
datasetFilesTrain
# Out:
# ['/home/inst/Downloads/AgentHuman/SeqTrain/data_05174.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06795.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05223.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05942.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06459.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05447.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04875.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04166.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05265.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06227.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06549.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04376.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04333.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04165.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05661.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05369.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06339.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05137.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05541.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05818.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04615.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05070.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04294.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04331.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06440.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04170.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06051.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06656.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04960.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03919.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06783.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06233.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06705.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03930.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05147.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04710.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05268.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05219.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05027.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05944.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04221.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06020.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05953.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05319.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06592.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06086.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05555.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05062.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06242.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05241.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05295.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06334.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03664.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06387.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03933.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03758.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05493.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04638.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05344.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06133.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06770.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03928.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05910.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04156.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06898.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06245.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05591.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03750.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05409.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05658.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06029.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05587.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03903.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06146.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04684.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05467.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06494.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05978.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03781.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06308.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05891.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04481.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06355.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04591.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05884.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06417.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06752.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05357.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03821.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04884.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03793.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05253.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06036.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06854.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04276.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04187.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03833.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04371.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05025.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03690.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05380.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04857.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04733.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06753.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04447.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06838.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03687.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05512.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05132.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06406.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05296.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03861.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04687.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05423.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03740.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05642.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03759.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03723.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03731.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04936.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05114.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06939.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06843.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04501.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05080.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03905.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06249.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06203.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03812.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03698.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06443.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04039.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04984.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05732.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05962.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06685.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05753.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04259.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05232.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03975.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06385.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05847.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05625.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05932.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05494.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04654.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06936.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06789.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04269.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05790.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04631.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05287.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05056.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06331.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06156.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06093.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04424.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06018.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04890.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04503.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04049.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06161.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04034.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05751.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05402.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06251.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05085.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04780.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06835.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05154.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05777.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05356.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06338.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05808.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03935.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06718.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06253.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06473.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06260.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05168.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06037.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03785.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06270.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05315.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04075.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05926.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04903.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04529.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04696.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06044.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05410.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04721.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05850.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06922.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04197.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04997.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04109.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05069.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03991.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06232.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05086.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05640.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06609.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06354.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05669.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05592.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06804.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05482.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05670.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06305.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04450.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05116.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06583.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03921.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06243.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04622.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04094.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06600.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04391.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06842.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05784.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06352.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03760.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04849.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04494.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05169.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03918.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03668.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04950.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06824.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06350.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05097.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06573.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04737.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04967.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04848.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05084.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04288.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05646.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06437.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04663.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06734.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03798.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05401.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06247.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06945.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03878.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05378.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04183.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04035.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06008.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05853.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04764.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05834.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05418.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04523.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06089.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04823.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05998.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06660.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06659.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05361.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05780.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04287.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06038.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05270.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05185.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04584.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04669.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06061.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05844.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04404.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04575.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04488.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03794.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06424.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04476.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05675.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03673.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05487.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05262.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06234.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04735.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04444.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05328.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03852.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03825.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04385.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06282.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04418.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06028.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06639.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05384.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04816.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06125.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05291.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06212.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05321.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04706.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05210.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03685.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06228.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06066.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04951.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06298.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05864.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04341.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04114.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05594.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05682.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05798.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06657.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05510.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05516.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05032.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05572.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04932.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06340.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05623.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06923.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05376.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04302.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03962.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04008.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05862.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05386.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03725.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04581.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04078.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04226.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03755.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06506.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05632.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05260.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05745.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04987.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03742.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05012.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06906.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04264.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06539.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04046.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05387.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06750.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04603.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03986.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05323.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05267.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04657.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05620.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04019.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03863.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06026.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05619.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06426.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03856.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04741.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06574.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03859.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05390.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04597.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06508.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05113.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05183.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05584.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05961.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05854.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04564.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05573.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06342.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05119.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06677.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03877.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06393.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05048.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06004.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03931.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04526.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05831.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04605.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06326.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05501.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05129.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05742.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04776.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05290.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04285.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05337.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03807.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04934.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05583.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06475.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05347.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05076.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06405.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05628.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04680.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06618.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04783.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03994.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04845.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04944.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06358.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05462.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06886.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06138.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04727.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04547.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06189.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05341.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04101.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05515.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04812.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05433.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04674.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03706.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06369.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05672.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05832.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05297.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04480.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06173.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06461.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05667.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05816.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03772.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06114.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05967.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06792.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04400.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04734.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04117.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04437.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05138.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06707.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04119.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06343.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06834.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05514.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05456.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05874.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03838.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04141.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04509.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04030.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05026.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06072.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04824.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04775.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04223.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03948.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06129.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04714.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04882.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06336.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05659.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05279.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05206.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04522.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06070.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06135.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04318.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04340.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05217.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06445.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05104.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06911.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06077.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04717.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06827.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05107.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04864.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03848.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05002.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04927.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06531.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03999.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04653.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04621.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04300.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06891.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03922.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05238.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04977.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06875.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04915.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05008.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06821.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06611.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03683.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05263.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04821.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06048.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04589.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04185.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04191.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03792.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05483.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05988.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04153.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06896.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06381.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05982.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06695.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06525.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06132.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06463.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06039.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03707.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05577.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05803.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05631.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03952.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04222.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03976.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04097.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06185.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06275.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05763.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03941.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05406.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04955.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04104.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06515.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06293.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05329.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03854.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04370.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06724.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04818.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05759.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05089.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04778.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05750.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04590.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05843.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06729.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06749.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05951.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05801.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04600.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05162.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04089.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04829.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05972.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04338.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04701.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06073.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05876.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06062.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04568.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05049.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06567.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06687.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05957.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06641.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04388.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06322.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06100.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04320.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05829.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04661.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04360.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04432.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03868.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04358.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04093.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06455.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03716.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06112.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04309.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04497.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06599.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04067.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04434.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03727.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05228.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03884.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06158.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05519.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05933.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05271.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05578.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05551.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05247.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05156.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06788.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04380.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05175.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04137.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06034.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06220.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05407.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05740.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03851.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06483.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05593.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04200.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05536.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04060.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05453.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05540.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06533.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04355.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05053.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04131.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03813.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04055.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06519.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03663.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04736.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06819.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05479.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05621.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04040.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03712.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04410.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03777.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05059.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05303.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05671.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04343.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04210.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05651.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05201.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04322.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04495.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05497.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06590.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05986.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04113.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05203.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04793.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04299.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06690.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06186.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06904.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05688.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06489.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05404.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06937.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04018.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06616.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04229.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04042.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04258.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06481.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06627.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05950.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04373.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03826.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04139.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06543.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03801.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04317.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05363.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05776.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05304.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05358.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04715.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04282.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03719.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05419.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04361.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04672.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03969.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04655.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04682.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04281.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04328.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05802.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05812.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05686.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06621.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05997.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05231.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04557.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04050.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06669.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05817.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05325.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04880.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03734.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05660.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04154.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04570.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03958.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06820.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04647.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06383.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06304.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06353.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04726.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06184.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06192.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06853.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04323.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04064.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04014.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05835.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04344.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06612.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03817.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06857.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05563.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05269.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05480.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04149.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03737.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04659.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06662.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05526.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06046.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04051.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04844.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04712.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03728.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04959.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04456.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06870.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06395.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05923.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05993.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04708.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04612.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05221.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05158.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04656.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04326.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06900.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03932.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03890.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05093.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05427.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06762.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03815.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04168.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04007.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05305.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06464.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06692.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04375.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06485.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04777.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05167.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06878.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04670.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06109.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05727.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05769.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05484.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03888.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05548.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06097.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04403.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06541.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06755.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03775.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06671.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05489.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05180.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06154.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04616.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03700.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06720.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05565.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04102.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06418.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06022.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05700.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05286.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04538.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06759.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06801.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06670.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04478.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05508.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06523.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03967.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04692.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04473.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05192.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04618.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04635.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06944.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06162.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05109.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06495.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05307.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04498.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04677.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04860.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06632.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04786.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05779.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04919.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06194.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05475.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04599.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04788.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05655.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06642.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04773.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06080.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04989.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04943.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05242.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05981.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05582.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05176.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04499.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06926.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06603.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06805.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06917.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03867.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04902.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06409.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04315.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04399.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06497.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04596.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04571.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05445.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06538.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04068.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06502.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03796.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03704.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04806.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06680.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05405.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06597.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06404.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05544.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06644.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05227.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03885.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05181.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06001.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04459.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06229.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06681.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06650.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04554.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04304.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05899.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03896.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05333.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06448.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05052.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06171.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06199.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06517.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06195.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05941.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05373.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06951.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03902.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05560.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05622.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05737.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05155.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04895.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04098.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06504.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05872.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04270.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04272.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06159.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06296.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06493.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06741.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05747.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03695.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05010.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06458.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06179.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06136.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04072.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04239.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05083.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06738.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05172.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05448.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04274.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05638.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05088.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03703.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04518.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06449.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03836.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03745.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03915.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05719.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04052.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05976.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04392.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06554.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05388.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05906.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03936.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04990.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04705.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05611.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05964.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05905.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04427.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04531.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06942.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06082.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05446.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05821.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06108.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05112.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05324.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06683.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05931.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05966.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04640.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04325.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04138.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05371.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03883.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05770.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06630.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04110.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06310.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05952.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05414.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05678.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04000.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05428.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04172.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03788.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06569.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04357.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04348.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06482.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06593.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04079.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04929.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05438.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05897.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06261.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05451.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05250.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06172.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04390.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04837.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06871.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06288.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06796.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05581.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04218.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05153.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03688.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06181.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05771.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06134.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06168.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06246.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06057.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04142.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05283.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05765.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03989.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06324.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04991.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06704.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04106.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05699.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05934.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04753.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03981.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04296.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04801.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06204.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04479.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05275.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06063.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04985.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06137.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04313.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06225.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04525.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_03776.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04846.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04452.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04540.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04528.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04171.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06823.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04082.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05819.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06737.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_04700.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_05244.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06902.h5',
#  '/home/inst/Downloads/AgentHuman/SeqTrain/data_06217.h5',
#  ...]

# %%
# understanding dataset
print(len(datasetFilesTrain), datasetFilesTrain[0], len(datasetFilesVal))

import h5py
dataset = h5py.File(datasetFilesTrain[120], 'r')


print(dataset)
print(dataset.keys())

print(dataset['rgb'].shape)

print(dataset['targets'].shape)

ind = 22

x = dataset['rgb'][ind]
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(x)
print (dataset.items())
image_h5 = dataset['rgb'][...]
measurements_h5 = dataset['targets'][...]
print (image_h5[1], measurements_h5[1])

# based on the info provided, note that yaw angle of the camera is recorded but not used
tgtNameList = ['Steer', 'Gas', 'Brake', 'Hand Brake,' 'Reverse Gear', 
               'Steer Noise', 'Gas Noise', 'Brake Noise', 'Position X', 
               'Position Y', 'Speed', 'Collision Other', 'Collision Pedestrian', 
               'Collision Car', 'Opposite Lane Inter', 'Sidewalk Intersect', 'Acceleration X',
               'Acceleration Y', 'Acceleration Z', 'Platform time', 'Game Time', 
               'Orientation X', 'Orientation Y', 'Orientation Z', 'Control signal', 'Noise', 'Camera']
dataset.close()
# Out:
# 3289 /home/inst/Downloads/AgentHuman/SeqTrain/data_05174.h5 374
# <HDF5 file "data_05114.h5" (mode r)>
# KeysView(<HDF5 file "data_05114.h5" (mode r)>)
# (200, 88, 200, 3)
# (200, 28)
# ItemsViewHDF5(<HDF5 file "data_05114.h5" (mode r)>)
# [[[  0   0   0]
#   [  0   1   0]
#   [  0   3   0]
#   ...
#   [115 128 136]
#   [115 128 135]
#   [114 127 135]]
#
#  [[  0   1   0]
#   [  0   2   0]
#   [  0   3   0]
#   ...
#   [116 129 137]
#   [116 129 136]
#   [115 128 135]]
#
#  [[  0   2   0]
#   [  0   1   0]
#   [  0   2   0]
#   ...
#   [118 130 138]
#   [117 130 138]
#   [117 129 137]]
#
#  ...
#
#  [[  1   3   7]
#   [  1   5   9]
#   [  1   3   9]
#   ...
#   [ 17  19  18]
#   [ 21  22  20]
#   [ 25  26  22]]
#
#  [[  1   3   9]
#   [  2   5  10]
#   [  2   6  10]
#   ...
#   [  3   7  11]
#   [  5   9  12]
#   [  7  11  13]]
#
#  [[  5   8  11]
#   [  4   7  10]
#   [  4   8  10]
#   ...
#   [  3   7  10]
#   [  4   8  12]
#   [  8  10  13]]] [-4.42722871e-04  5.00000000e-01  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -4.42722871e-04  5.00000000e-01  0.00000000e+00
#   3.34669375e+04  5.16530127e+03  1.60828495e+01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   1.41533455e-02  1.25484452e-01 -1.62317639e-03  6.97962816e+08
#   3.32320000e+04 -1.25238895e-02  9.99921501e-01  3.50713701e-04
#   5.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]

# %%
## Generator: generator train data batches and branches

import itertools

def genData(fileNames = datasetFilesTrain, batchSize = 200):
    #fileNames = datasetFilesTrain
    #branchNum = 3 # Control signal, int ( 2 Follow lane, 3 Left, 4 Right, 5 Straight)
    #batchSize = 200 
    batchX = np.zeros((batchSize, 88, 200, 3))    
    batchY = np.zeros((batchSize, 28))
    idx = 0       
    while True: # to make sure we never reach the end
        counter = 0
        while counter<=batchSize-1:
            idx = np.random.randint(len(fileNames)-1) 
            try:
                data = h5py.File(fileNames[idx], 'r')
            except: 
                print(idx, fileNames[idx])
            
            dataIdx = np.random.randint(200-1) 
            batchX[counter] = data['rgb'][dataIdx]
            batchY[counter] = data['targets'][dataIdx]
            counter += 1
            data.close()
        yield (batchX, batchY)

def genBranch(fileNames = datasetFilesTrain, branchNum = 3, batchSize = 200):
    #fileNames = datasetFilesTrain
    #branchNum = 3 # Control signal, int ( 2 Follow lane, 3 Left, 4 Right, 5 Straight)
    #batchSize = 200 
    batchX = np.zeros((batchSize, 88, 200, 3))    
    batchY = np.zeros((batchSize, 28))
    idx = 0       
    while True: # to make sure we never reach the end
        counter = 0
        while counter<=batchSize-1:
            idx = np.random.randint(len(fileNames)-1) 
            try:
                data = h5py.File(fileNames[idx], 'r')
            except: 
                print(idx, fileNames[idx])
            
            dataIdx = np.random.randint(200-1) 
            if data['targets'][dataIdx][24] == branchNum:
                batchX[counter] = data['rgb'][dataIdx]
                batchY[counter] = data['targets'][dataIdx]
                counter += 1
                data.close()
        yield (batchX, batchY)

# %%
## Data Augmentation (from https://github.com/carla-simulator/imitation-learning/issues/39)
import imgaug as ia
from imgaug import augmenters as iaa
import numpy as np

st = lambda aug: iaa.Sometimes(0.4, aug)
oc = lambda aug: iaa.Sometimes(0.3, aug)
rl = lambda aug: iaa.Sometimes(0.09, aug)
seq = iaa.Sequential([
        rl(iaa.GaussianBlur((0, 1.5))), # blur images with a sigma between 0 and 1.5
        rl(iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05), per_channel=0.5)), # add gaussian noise to images
        oc(iaa.Dropout((0.0, 0.10), per_channel=0.5)), # randomly remove up to X% of the pixels
        oc(iaa.CoarseDropout((0.0, 0.10), size_percent=(0.08, 0.2),per_channel=0.5)), # randomly remove up to X% of the pixels
        oc(iaa.Add((-40, 40), per_channel=0.5)), # change brightness of images (by -X to Y of original value)
        st(iaa.Multiply((0.10, 2.5), per_channel=0.2)), # change brightness of images (X-Y% of original value)
        rl(iaa.ContrastNormalization((0.5, 1.5), per_channel=0.5)), # improve or worsen the contrast
        #rl(iaa.Grayscale((0.0, 1))), # put grayscale
], random_order=True)

# %%
# Test augmentors
ia.seed(1)

# Example batch of images.
# The array has shape (32, 64, 64, 3) and dtype uint8.
images = np.array(
    [ia.quokka(size=(64, 64)) for _ in range(32)],
    dtype=np.uint8
)

images_aug = seq.augment_images(images)
images_aug.shape

plotSpecialTool(images_aug,np.zeros([len(images_aug),1]),samples2Visualize=18,factors=[3,6],figSize=(12,6),grayFlag=False)

# %%
## MODEL

# source: https://github.com/carla-simulator/imitation-learning
import numpy as np

import tensorflow as tf


def weight_ones(shape, name):
    initial = tf.constant(1.0, shape=shape, name=name)
    return tf.Variable(initial)


def weight_xavi_init(shape, name):
    initial = tf.get_variable(name=name, shape=shape, initializer=tf.contrib.layers.xavier_initializer())
    return initial


def bias_variable(shape, name):
    initial = tf.constant(0.1, shape=shape, name=name)
    return tf.Variable(initial)


class Network(object):

    def __init__(self, dropout, image_shape):
        """ We put a few counters to see how many times we called each function """
        self._dropout_vec = dropout
        self._image_shape = image_shape
        self._count_conv = 0
        self._count_pool = 0
        self._count_bn = 0
        self._count_activations = 0
        self._count_dropouts = 0
        self._count_fc = 0
        self._count_lstm = 0
        self._count_soft_max = 0
        self._conv_kernels = []
        self._conv_strides = []
        self._weights = {}
        self._features = {}
        
    """ Our conv is currently using bias """

    def conv(self, x, kernel_size, stride, output_size, padding_in='SAME'):
        self._count_conv += 1

        filters_in = x.get_shape()[-1]
        shape = [kernel_size, kernel_size, filters_in, output_size]

        weights = weight_xavi_init(shape, 'W_c_' + str(self._count_conv))
        bias = bias_variable([output_size], name='B_c_' + str(self._count_conv))

        self._weights['W_conv' + str(self._count_conv)] = weights
        self._conv_kernels.append(kernel_size)
        self._conv_strides.append(stride)

        conv_res = tf.add(tf.nn.conv2d(x, weights, [1, stride, stride, 1], padding=padding_in,
                                       name='conv2d_' + str(self._count_conv)), bias,
                          name='add_' + str(self._count_conv))

        self._features['conv_block' + str(self._count_conv - 1)] = conv_res

        return conv_res

    def max_pool(self, x, ksize=3, stride=2):
        self._count_pool += 1
        return tf.nn.max_pool(x, ksize=[1, ksize, ksize, 1], strides=[1, stride, stride, 1],
                              padding='SAME', name='max_pool' + str(self._count_pool))

    def bn(self, x):
        self._count_bn += 1
        return tf.contrib.layers.batch_norm(x, is_training=False,
                                            updates_collections=None, scope='bn' + str(self._count_bn))

    def activation(self, x):
        self._count_activations += 1
        return tf.nn.relu(x, name='relu' + str(self._count_activations))

    def dropout(self, x):
        print ("Dropout", self._count_dropouts)
        self._count_dropouts += 1
        output = tf.nn.dropout(x, self._dropout_vec[self._count_dropouts - 1],
                               name='dropout' + str(self._count_dropouts))

        return output
    
    def fc(self, x, output_size):
        self._count_fc += 1
        filters_in = x.get_shape()[-1]
        shape = [filters_in, output_size]

        weights = weight_xavi_init(shape, 'W_f_' + str(self._count_fc))
        bias = bias_variable([output_size], name='B_f_' + str(self._count_fc))

        return tf.nn.xw_plus_b(x, weights, bias, name='fc_' + str(self._count_fc))

    def conv_block(self, x, kernel_size, stride, output_size, padding_in='SAME'):
        print (" === Conv", self._count_conv, "  :  ", kernel_size, stride, output_size)
        with tf.name_scope("conv_block" + str(self._count_conv)):
            x = self.conv(x, kernel_size, stride, output_size, padding_in=padding_in)
            x = self.bn(x)
            x = self.dropout(x)

            return self.activation(x)

    def fc_block(self, x, output_size):
        print (" === FC", self._count_fc, "  :  ", output_size)
        with tf.name_scope("fc" + str(self._count_fc + 1)):
            x = self.fc(x, output_size)
            x = self.dropout(x)
            self._features['fc_block' + str(self._count_fc + 1)] = x
            return self.activation(x)

    def get_weigths_dict(self):
        return self._weights

    def get_feat_tensors_dict(self):
        return self._features

# %%
# source: https://github.com/carla-simulator/imitation-learning
def load_imitation_learning_network(input_image, input_data, input_size, dropout):
    branches = []

    x = input_image

    network_manager = Network(dropout, tf.shape(x))

    """conv1"""  # kernel sz, stride, num feature maps
    xc = network_manager.conv_block(x, 5, 2, 32, padding_in='VALID')
    print( xc)
    xc = network_manager.conv_block(xc, 3, 1, 32, padding_in='VALID')
    print( xc)

    """conv2"""
    xc = network_manager.conv_block(xc, 3, 2, 64, padding_in='VALID')
    print( xc)
    xc = network_manager.conv_block(xc, 3, 1, 64, padding_in='VALID')
    print( xc)

    """conv3"""
    xc = network_manager.conv_block(xc, 3, 2, 128, padding_in='VALID')
    print( xc)
    xc = network_manager.conv_block(xc, 3, 1, 128, padding_in='VALID')
    print( xc)

    """conv4"""
    xc = network_manager.conv_block(xc, 3, 1, 256, padding_in='VALID')
    print( xc)
    xc = network_manager.conv_block(xc, 3, 1, 256, padding_in='VALID')
    print( xc)
    """mp3 (default values)"""

    """ reshape """
    x = tf.reshape(xc, [-1, int(np.prod(xc.get_shape()[1:]))], name='reshape')
    print( x)

    """ fc1 """
    x = network_manager.fc_block(x, 512)
    print( x)
    """ fc2 """
    x = network_manager.fc_block(x, 512)
    
    """Process Control"""

    """ Speed (measurements)"""
    with tf.name_scope("Speed"):
        speed = input_data[1]  # get the speed from input data
        speed = network_manager.fc_block(speed, 128)
        speed = network_manager.fc_block(speed, 128)

    """ Joint sensory """
    j = tf.concat([x, speed], 1)
    j = network_manager.fc_block(j, 512)

    """Start BRANCHING"""
    branch_config = [["Steer", "Gas", "Brake"], ["Steer", "Gas", "Brake"], \
                     ["Steer", "Gas", "Brake"], ["Steer", "Gas", "Brake"], ["Speed"]]

    for i in range(0, len(branch_config)):
        with tf.name_scope("Branch_" + str(i)):
            if branch_config[i][0] == "Speed":
                # we only use the image as input to speed prediction
                branch_output = network_manager.fc_block(x, 256)
                branch_output = network_manager.fc_block(branch_output, 256)
            else:
                branch_output = network_manager.fc_block(j, 256)
                branch_output = network_manager.fc_block(branch_output, 256)

            branches.append(network_manager.fc(branch_output, len(branch_config[i])))

        print (branch_output)

    return branches

# %%
from keras.layers import ConvLSTM2D, MaxPool3D, BatchNormalization, MaxPool2D
from tensorflow.contrib.layers import batch_norm
def controlNet(inputs, targets, shape, dropoutVec, branchConfig, params, scopeName = 'controlNET'):
    """
        Get one image/sequence of images to predict control operations for controling the vehicle
        inputs: N Batch of M images in order
        shape: [BatchSize, SeqSize, FrameHeight, FrameWeight, Channels]
        phase: placeholder for training
        scopeName: TensorFlow Scope Name to separate nets in the graph
    """
    with tf.variable_scope(scopeName) as scope:
        with tf.name_scope("Network"):
            
            networkTensor = load_imitation_learning_network(inputs[0], inputs[1],
                                                  shape[1:3], dropoutVec)
            solverList = []
            lossList = []
            trainVars = tf.trainable_variables()
            for i in range(0, len(branchConfig)):
                with tf.name_scope("Branch_" + str(i)):
                    if branchConfig[i][0] == "Speed":
                        # we only use the image as input to speed prediction
                        contLoss = tf.reduce_mean(tf.square(tf.subtract(networkTensor[-1], targets[0]))) #+ tf.add_n([tf.nn.l2_loss(v) for v in trainVars]) * L2NormConst
                        contSolver = tf.train.AdamOptimizer(learning_rate=params[3], beta1=params[4], beta2=params[5]).minimize(contLoss)
                        solverList.append(contSolver)
                        lossList.append(contLoss)
                        # create a summary to monitor cost tensor
                        tf.summary.scalar("Speed_Loss", contLoss)
                    else:
                        contLoss = tf.reduce_mean(tf.square(tf.subtract(networkTensor[i], targets[1]))) #+ tf.add_n([tf.nn.l2_loss(v) for v in trainVars]) * L2NormConst
                        contSolver = tf.train.AdamOptimizer(learning_rate=params[3], beta1=params[4], beta2=params[5]).minimize(contLoss)
                        solverList.append(contSolver)
                        lossList.append(contLoss)  
                        tf.summary.scalar("Control_Loss_Branch_"+str(i), contLoss)
        
        tensors = {
            'optimizers' : solverList,
            'losses' : lossList,
            'output' : networkTensor
        }
    return tensors

# %%
## Model Define
import tensorflow as tf
#params = [trainScratch, dropoutVec, image_cut, learningRate, beta1, beta2, num_images, iterNum, batchSize, valBatchSize, NseqVal, epochs, samplesPerEpoch, L2NormConst]
def Net(branchConfig, params, timeNumberFrames, prefSize=(128, 160, 3)):   
    shapeInput = [None, prefSize[0], prefSize[1], prefSize[2]]
    inputImages = tf.placeholder("float", shape=[None, prefSize[0], prefSize[1],
                                                                 prefSize[2]], name="input_image")
    inputData = []
    inputData.append(tf.placeholder(tf.float32,
                                           shape=[None, 4], name="input_control"))
    inputData.append(tf.placeholder(tf.float32,
                                           shape=[None, 1], name="input_speed"))
    
    inputs = [inputImages,inputData]
    dout = tf.placeholder("float", shape=[len(params[1])]) 

    targetSpeed = tf.placeholder(tf.float32, shape=[None, 1], name="target_speed")
    targetController = tf.placeholder(tf.float32, shape=[None, 3], name="target_control")
    
    targets = [targetSpeed, targetController]

    print('Building ControlNet ...')    
    controlOpTensors = controlNet(inputs, targets, shapeInput, dout, branchConfig, params, scopeName = 'controlNET')
    
    tensors = {
            'inputs' : inputs,
            'targets' : targets,
            'params' : params,
            'dropoutVec' : dout,
            'output' : controlOpTensors
        }
    return tensors # [ inputs['inputImages','inputData'], targets['targetSpeed', 'targetController'],  'params', dropoutVec', output[optimizers, losses, branchesOutputs] ]

# %%
## Build and Train
trainScratch = True
tf.reset_default_graph()
sessGraph = tf.Graph()

# %%
from tensorflow.core.protobuf import saver_pb2
from IPython.display import clear_output
import time

# use many gpus
config = tf.ConfigProto(allow_soft_placement = True)

tf.reset_default_graph()
sessGraph = tf.Graph()

# Prepare data generators
batchListGenTrain = []
batchListGenVal = []
batchListName = []
for i in range(len(branchConfig)):
    with tf.name_scope("Branch_" + str(i)):
        if branchConfig[i][0] == "Speed":
            miniBatchGen = genData(fileNames = datasetFilesTrain, batchSize = batchSize)
            batchListGenTrain.append(miniBatchGen)
            miniBatchGen = genData(fileNames = datasetFilesVal, batchSize = batchSize)
            batchListGenVal.append(miniBatchGen)
        else:
            miniBatchGen = genBranch(fileNames = datasetFilesTrain, branchNum = controlInputs[i], batchSize = batchSize)
            batchListGenTrain.append(miniBatchGen)
            miniBatchGen = genBranch(fileNames = datasetFilesVal, branchNum = controlInputs[i], batchSize = batchSize)
            batchListGenVal.append(miniBatchGen)   

with sessGraph.as_default():
    sess = tf.Session(graph=sessGraph, config = config)
    with sess.as_default():
        
        # build model
        print('Building Net ...')
        netTensors = Net(branchConfig, params, timeNumberFrames, prefSize)
        print(netTensors['output'])

        print('Initialize Variables in the Graph ...')
        sess.run(tf.global_variables_initializer()) # initialize variables
        
        # merge all summaries into a single op
        merged_summary_op = tf.summary.merge_all()

        saver = tf.train.Saver(write_version = saver_pb2.SaverDef.V2)
        if not(trainScratch):
            saver.restore(sess, "test/model.ckpt") # restore trained parameters

        # op to write logs to Tensorboard
        logsPath = './logs'
        modelPath = './test/'
        summary_writer = tf.summary.FileWriter(logsPath, graph=sessGraph)
        print('Start Training process ...')
        
        steps = 0
        for epoch in range(epochs):
            tStartEpoch = time.time()
            print("  Epoch:", epoch)
            for j in range(int(num_images/batchSize)):
                steps += 1
                for i in range(0, len(branchConfig)):

                        xs , ys = next(batchListGenTrain[i])
                        
                        # augment images
                        xs = seq.augment_images(xs)
                        
                        contSolver = netTensors['output']['optimizers'][i]#solverList[i]
                        contLoss = netTensors['output']['losses'][i]#lossList[i]

                        inputData = []
                        inputData.append(sess.run(tf.one_hot(ys[:,24],4))) # Command Control
                        inputData.append(ys[:,10].reshape([batchSize,1])) # Speed 
                        
                        # [ inputs['inputImages','inputData'], targets['targetSpeed', 'targetController'],  'params', dropoutVec', output[optimizers, losses, branchesOutputs] ]
                        feedDict = {netTensors['inputs'][0]: xs, netTensors['inputs'][1][0]: inputData[0], netTensors['inputs'][1][1]: inputData[1], netTensors['dropoutVec']: dropoutVec, netTensors['targets'][0]: ys[:,10].reshape([120,1]), netTensors['targets'][1]: ys[:,0:3]}                       
                        _,loss_value = sess.run([contSolver, contLoss], feed_dict = feedDict)
                        
                        # write logs at every iteration
                        feedDict = {netTensors['inputs'][0]: xs, netTensors['inputs'][1][0]: inputData[0], netTensors['inputs'][1][1]: inputData[1], netTensors['dropoutVec']: [1] * len(dropoutVec), netTensors['targets'][0]: ys[:,10].reshape([120,1]), netTensors['targets'][1]: ys[:,0:3]}                       
                        summary = merged_summary_op.eval(feed_dict=feedDict)
                        summary_writer.add_summary(summary, epoch * num_images/batchSize + j)

                        print("  Train::: Epoch: %d, Step: %d, TotalSteps: %d, Loss: %g" % (epoch, epoch * batchSize + j, steps, loss_value), cBranchesOutList[i])
                        
                        if steps % 10 == 0:
                            #clear_output(wait=True)netTensors
                            xs, ys = next(batchListGenVal[i])
                            contLoss = netTensors['output']['losses'][i]
                            feedDict = {netTensors['inputs'][0]: xs, netTensors['inputs'][1][0]: inputData[0], netTensors['inputs'][1][1]: inputData[1], netTensors['dropoutVec']: [1] * len(dropoutVec), netTensors['targets'][0]: ys[:,10].reshape([120,1]), netTensors['targets'][1]: ys[:,0:3]}                       
                            loss_value = contLoss.eval(feed_dict=feedDict)
                            print("  Val::: Epoch: %d, Step: %d, TotalSteps: %d, Loss: %g" % (epoch, epoch * batchSize + j, steps, loss_value), cBranchesOutList[i])
                if steps % 10 == 0:
                    clear_output(wait=True)

                if steps % 50 == 0 and steps!=0: # batchSize
                    print(j%50, '  Save Checkpoint ...')
                    if not os.path.exists(modelPath):
                        os.makedirs(modelPath)
                    checkpoint_path = os.path.join(modelPath, "model.ckpt")
                    filename = saver.save(sess, checkpoint_path)
                    print("  Model saved in file: %s" % filename)

                if steps % 50000 == 0 and steps!=0: # every 50000 step, multiply learning rate by half
                    print("Half the learning rate ....")
                    solverList = []
                    lossList = []
                    trainVars = tf.trainable_variables()
                    for i in range(0, len(branchConfig)):
                        with tf.name_scope("Branch_" + str(i)):
                            if branchConfig[i][0] == "Speed":
                                # we only use the image as input to speed prediction
                                #if not (j == 0):
                                # [ inputs['inputImages','inputData'], targets['targetSpeed', 'targetController'],  'params', dropoutVec', output[optimizers, losses, branchesOutputs] ]
                                # params = [trainScratch, dropoutVec, image_cut, learningRate, beta1, beta2, num_images, iterNum, batchSize, valBatchSize, NseqVal, epochs, samplesPerEpoch, L2NormConst]                
                                params[3] = params[3] * 0.5 # update Learning Rate
                                contLoss = tf.reduce_mean(tf.square(tf.subtract(netTensors['output']['branchesOutputs'][-1], netTensors['targets'][0]))) #+ tf.add_n([tf.nn.l2_loss(v) for v in trainVars]) * L2NormConst
                                contSolver = tf.train.AdamOptimizer(learning_rate=params[3], beta1=params[4], beta2=params[5]).minimize(contLoss)
                                solverList.append(contSolver)
                                lossList.append(contLoss)
                                # create a summary to monitor cost tensor
                                tf.summary.scalar("Speed_Loss", contLoss)
                            else:
                                #if not (j == 0):
                                params[3] = params[3] * 0.5
                                contLoss = tf.reduce_mean(tf.square(tf.subtract(netTensors['output']['branchesOutputs'][i], netTensors['targets'][1]))) #+ tf.add_n([tf.nn.l2_loss(v) for v in trainVars]) * L2NormConst
                                contSolver = tf.train.AdamOptimizer(learning_rate=params[3], beta1=params[4], beta2=params[5]).minimize(contLoss)
                                solverList.append(contSolver)
                                lossList.append(contLoss)  
                                tf.summary.scalar("Control_Loss_Branch_"+str(i), contLoss)
                                
                    # update new Losses and Optimizers 
                    print('Initialize Variables in the Graph ...')
                    # merge all summaries into a single op
                    merged_summary_op = tf.summary.merge_all()
                    sess.run(tf.global_variables_initializer())
                    saver.restore(sess, "test/model.ckpt") # restore trained parameters

                if steps % 294000 == 0 and steps!=0:
                    # finish the training
                    break
            if steps % 294000 == 0 and steps!=0:
                # finish the training
                print('Finalize the training and Save Checkpoint ...')
                if not os.path.exists(modelPath):
                    os.makedirs(modelPath)
                checkpoint_path = os.path.join(modelPath, "model.ckpt")
                filename = saver.save(sess, checkpoint_path)
                print("  Model saved in file: %s" % filename)
                break

            tStopEpoch = time.time()
            print ("  Epoch Time Cost:", round(tStopEpoch - tStartEpoch,2), "s" )
# Out:
#   Train::: Epoch: 0, Step: 10, TotalSteps: 11, Loss: 0.991015 Follow Lane
#   Train::: Epoch: 0, Step: 10, TotalSteps: 11, Loss: 0.654419 Go Left
#   Train::: Epoch: 0, Step: 10, TotalSteps: 11, Loss: 0.558202 Go Right
#   Train::: Epoch: 0, Step: 10, TotalSteps: 11, Loss: 0.935777 Go Straight
#   Train::: Epoch: 0, Step: 10, TotalSteps: 11, Loss: 279.571 Speed Prediction Branch
#   Train::: Epoch: 0, Step: 11, TotalSteps: 12, Loss: 0.928037 Follow Lane
#   Train::: Epoch: 0, Step: 11, TotalSteps: 12, Loss: 0.686201 Go Left
#   Train::: Epoch: 0, Step: 11, TotalSteps: 12, Loss: 0.623901 Go Right
#   Train::: Epoch: 0, Step: 11, TotalSteps: 12, Loss: 0.79584 Go Straight
#   Train::: Epoch: 0, Step: 11, TotalSteps: 12, Loss: 237.011 Speed Prediction Branch
#   Train::: Epoch: 0, Step: 12, TotalSteps: 13, Loss: 0.790355 Follow Lane
# 2190 /home/inst/Downloads/AgentHuman/SeqTrain/data_06790.h5
#   Train::: Epoch: 0, Step: 12, TotalSteps: 13, Loss: 0.661445 Go Left
#   Train::: Epoch: 0, Step: 12, TotalSteps: 13, Loss: 0.600338 Go Right
#   Train::: Epoch: 0, Step: 12, TotalSteps: 13, Loss: 0.638976 Go Straight
#   Train::: Epoch: 0, Step: 12, TotalSteps: 13, Loss: 179.921 Speed Prediction Branch
#   Train::: Epoch: 0, Step: 13, TotalSteps: 14, Loss: 0.556314 Follow Lane
#   Train::: Epoch: 0, Step: 13, TotalSteps: 14, Loss: 0.513341 Go Left
#   Train::: Epoch: 0, Step: 13, TotalSteps: 14, Loss: 0.556819 Go Right
#   Train::: Epoch: 0, Step: 13, TotalSteps: 14, Loss: 0.60599 Go Straight
#   Train::: Epoch: 0, Step: 13, TotalSteps: 14, Loss: 252.204 Speed Prediction Branch
#   Train::: Epoch: 0, Step: 14, TotalSteps: 15, Loss: 0.545457 Follow Lane
#   Train::: Epoch: 0, Step: 14, TotalSteps: 15, Loss: 0.477077 Go Left
#   Train::: Epoch: 0, Step: 14, TotalSteps: 15, Loss: 0.411825 Go Right
#   Train::: Epoch: 0, Step: 14, TotalSteps: 15, Loss: 0.724122 Go Straight
#   Train::: Epoch: 0, Step: 14, TotalSteps: 15, Loss: 176.075 Speed Prediction Branch
#   Train::: Epoch: 0, Step: 15, TotalSteps: 16, Loss: 0.459377 Follow Lane
#   Train::: Epoch: 0, Step: 15, TotalSteps: 16, Loss: 0.496461 Go Left
#   Train::: Epoch: 0, Step: 15, TotalSteps: 16, Loss: 0.409143 Go Right
#   Train::: Epoch: 0, Step: 15, TotalSteps: 16, Loss: 0.639355 Go Straight
#   Train::: Epoch: 0, Step: 15, TotalSteps: 16, Loss: 243.322 Speed Prediction Branch
#   Train::: Epoch: 0, Step: 16, TotalSteps: 17, Loss: 0.51183 Follow Lane
#   Train::: Epoch: 0, Step: 16, TotalSteps: 17, Loss: 0.459614 Go Left
#   Train::: Epoch: 0, Step: 16, TotalSteps: 17, Loss: 0.293363 Go Right
#   Train::: Epoch: 0, Step: 16, TotalSteps: 17, Loss: 0.39482 Go Straight
#   Train::: Epoch: 0, Step: 16, TotalSteps: 17, Loss: 163.854 Speed Prediction Branch
#   Train::: Epoch: 0, Step: 17, TotalSteps: 18, Loss: 0.468703 Follow Lane
#   Train::: Epoch: 0, Step: 17, TotalSteps: 18, Loss: 0.388302 Go Left
# 2190 /home/inst/Downloads/AgentHuman/SeqTrain/data_06790.h5
# ------------------------------------------------------------------
# ValueError                       Traceback (most recent call last)
# <ipython-input-45-4b7ac011d221> in <module>()
#      59                 for i in range(0, len(branchConfig)):
#      60
# ---> 61                         xs , ys = next(batchListGenTrain[i])
#      62
#      63                         # augment images
#
# <ipython-input-23-b356cee81d66> in genBranch(fileNames, branchNum, batchSize)
#      41
#      42             dataIdx = np.random.randint(200-1)
# ---> 43             if data['targets'][dataIdx][24] == branchNum:
#      44                 batchX[counter] = data['rgb'][dataIdx]
#      45                 batchY[counter] = data['targets'][dataIdx]
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/anaconda3/envs/CARLA_CUDA/lib/python3.5/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     175                 raise ValueError("Invalid HDF5 object reference")
#     176         else:
# --> 177             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     178
#     179         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# ValueError: Not a location (invalid object ID)
